# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("compensation data.csv")
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# 4             36288
# ...             ...
# 25968         15800
# 25969         62456
# 25970           923
# 25971         60609
# 25972           493
#
# [25973 rows x 6 columns]

# %%
headers = df.columns.tolist()
headers
# Out:
# ['experience_coding',
#  'python_user',
#  'r_user',
#  'sql_user',
#  'most_used',
#  'compensation']

# %%
df.loc[0:]
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# 4             36288
# ...             ...
# 25968         15800
# 25969         62456
# 25970           923
# 25971         60609
# 25972           493
#
# [25973 rows x 6 columns]

# %%
df["experience_coding"].dtype
# Out:
# dtype('float64')

# %%
def categorize_experience(experience):
    if experience < 5:
        return "less than 5 years"
    elif experience < 10:
        return "5-10 years"
    elif experience < 15:
        return "10-15 years"
    elif experience < 20:
        return "15-20 years"
    elif experience < 25:
        return "20-25 years"
    else:
        return "25+ years"

# %%
df['experience_category'] = df['experience_coding'].apply(categorize_experience)

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation experience_category
# 0            124267          5-10 years
# 1            236889         10-15 years
# 2             74321   less than 5 years
# 3             62593   less than 5 years
# 4             36288   less than 5 years
# ...             ...                 ...
# 25968         15800   less than 5 years
# 25969         62456   less than 5 years
# 25970           923   less than 5 years
# 25971         60609          5-10 years
# 25972           493   less than 5 years
#
# [25973 rows x 7 columns]
